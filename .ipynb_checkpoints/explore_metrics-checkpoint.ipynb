# %%
import json
import pprint

import kafka

# %%
consumer = kafka.KafkaConsumer('metricsets', bootstrap_servers=['192.168.72.2:9092'], value_deserializer=json.loads)

# %%
for index, record in enumerate(consumer):
    pprint.pprint(record.value)
    if index > 10:
        break
# Out:
# {'@timestamp': '2017-04-27T23:08:17.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 26},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8892},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0511},
#                     'user': {'pct': 0.0598}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:17.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 38},
#  'system': {'memory': {'actual': {'free': 4477415424,
#                                   'used': {'bytes': 12702453760,
#                                            'pct': 0.7394}},
#                        'free': 99782656,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17080086528, 'pct': 0.9942}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:17.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 65},
#  'system': {'load': {'1': 3.5171,
#                      '15': 3.2485,
#                      '5': 3.2769,
#                      'norm': {'1': 0.4396, '15': 0.4061, '5': 0.4096}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:18.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 36},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.9184},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0414},
#                     'user': {'pct': 0.0402}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:18.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 79},
#  'system': {'memory': {'actual': {'free': 4476637184,
#                                   'used': {'bytes': 12703232000,
#                                            'pct': 0.7394}},
#                        'free': 103067648,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17076801536, 'pct': 0.994}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:18.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 112},
#  'system': {'load': {'1': 3.5171,
#                      '15': 3.2485,
#                      '5': 3.2769,
#                      'norm': {'1': 0.4396, '15': 0.4061, '5': 0.4096}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:19.994Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 41},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.9226},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0412},
#                     'user': {'pct': 0.0362}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:19.994Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 40},
#  'system': {'memory': {'actual': {'free': 4444532736,
#                                   'used': {'bytes': 12735336448,
#                                            'pct': 0.7413}},
#                        'free': 78626816,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17101242368, 'pct': 0.9954}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:19.995Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 65},
#  'system': {'load': {'1': 3.5171,
#                      '15': 3.2485,
#                      '5': 3.2769,
#                      'norm': {'1': 0.4396, '15': 0.4061, '5': 0.4096}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:20.999Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 44},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.9124},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0401},
#                     'user': {'pct': 0.0476}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:20.999Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 109},
#  'system': {'load': {'1': 3.5171,
#                      '15': 3.2485,
#                      '5': 3.2769,
#                      'norm': {'1': 0.4396, '15': 0.4061, '5': 0.4096}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:20.999Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 81},
#  'system': {'memory': {'actual': {'free': 4405047296,
#                                   'used': {'bytes': 12774821888,
#                                            'pct': 0.7436}},
#                        'free': 43716608,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17136152576, 'pct': 0.9975}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:21.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 35},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8464},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0699},
#                     'user': {'pct': 0.0836}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:21.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 61},
#  'system': {'memory': {'actual': {'free': 4493717504,
#                                   'used': {'bytes': 12686151680,
#                                            'pct': 0.7384}},
#                        'free': 81485824,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17098383360, 'pct': 0.9953}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:21.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 83},
#  'system': {'load': {'1': 3.4756,
#                      '15': 3.2471,
#                      '5': 3.272,
#                      'norm': {'1': 0.4344, '15': 0.4059, '5': 0.409}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:22.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 31},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8959},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0452},
#                     'user': {'pct': 0.059}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:22.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 49},
#  'system': {'memory': {'actual': {'free': 4516110336,
#                                   'used': {'bytes': 12663758848,
#                                            'pct': 0.7371}},
#                        'free': 134811648,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17045057536, 'pct': 0.9922}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:22.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 76},
#  'system': {'load': {'1': 3.4756,
#                      '15': 3.2471,
#                      '5': 3.272,
#                      'norm': {'1': 0.4344, '15': 0.4059, '5': 0.409}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:23.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 33},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8744},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0485},
#                     'user': {'pct': 0.0771}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:23.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 65},
#  'system': {'memory': {'actual': {'free': 4515893248,
#                                   'used': {'bytes': 12663975936,
#                                            'pct': 0.7371}},
#                        'free': 134914048,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17044955136, 'pct': 0.9921}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:23.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 94},
#  'system': {'load': {'1': 3.4756,
#                      '15': 3.2471,
#                      '5': 3.272,
#                      'norm': {'1': 0.4344, '15': 0.4059, '5': 0.409}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:24.994Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 32},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.9084},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0502},
#                     'user': {'pct': 0.0414}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:24.994Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 36},
#  'system': {'memory': {'actual': {'free': 4521906176,
#                                   'used': {'bytes': 12657963008,
#                                            'pct': 0.7368}},
#                        'free': 141639680,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17038229504, 'pct': 0.9918}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:24.995Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 62},
#  'system': {'load': {'1': 3.4756,
#                      '15': 3.2471,
#                      '5': 3.272,
#                      'norm': {'1': 0.4344, '15': 0.4059, '5': 0.409}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:25.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 28},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.92},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.04},
#                     'user': {'pct': 0.04}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:25.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 50},
#  'system': {'memory': {'actual': {'free': 4521562112,
#                                   'used': {'bytes': 12658307072,
#                                            'pct': 0.7368}},
#                        'free': 141365248,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17038503936, 'pct': 0.9918}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:25.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 71},
#  'system': {'load': {'1': 3.4756,
#                      '15': 3.2471,
#                      '5': 3.272,
#                      'norm': {'1': 0.4344, '15': 0.4059, '5': 0.409}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:26.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 45},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8705},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0535},
#                     'user': {'pct': 0.076}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:26.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 78},
#  'system': {'memory': {'actual': {'free': 4520886272,
#                                   'used': {'bytes': 12658982912,
#                                            'pct': 0.7368}},
#                        'free': 142077952,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17037791232, 'pct': 0.9917}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:26.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 130},
#  'system': {'load': {'1': 3.6777,
#                      '15': 3.2632,
#                      '5': 3.3169,
#                      'norm': {'1': 0.4597, '15': 0.4079, '5': 0.4146}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:27.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 27},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8338},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0575},
#                     'user': {'pct': 0.1088}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:27.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 56},
#  'system': {'memory': {'actual': {'free': 4495765504,
#                                   'used': {'bytes': 12684103680,
#                                            'pct': 0.7383}},
#                        'free': 117002240,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17062866944, 'pct': 0.9932}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:27.998Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 80},
#  'system': {'load': {'1': 3.6777,
#                      '15': 3.2632,
#                      '5': 3.3169,
#                      'norm': {'1': 0.4597, '15': 0.4079, '5': 0.4146}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:28.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 26},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8496},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0514},
#                     'user': {'pct': 0.099}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:28.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 52},
#  'system': {'memory': {'actual': {'free': 4506738688,
#                                   'used': {'bytes': 12673130496,
#                                            'pct': 0.7377}},
#                        'free': 149630976,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17030238208, 'pct': 0.9913}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:28.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 64},
#  'system': {'load': {'1': 3.6777,
#                      '15': 3.2632,
#                      '5': 3.3169,
#                      'norm': {'1': 0.4597, '15': 0.4079, '5': 0.4146}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:29.994Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 20},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8582},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0502},
#                     'user': {'pct': 0.0916}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:29.994Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 417},
#  'system': {'memory': {'actual': {'free': 4504772608,
#                                   'used': {'bytes': 12675096576,
#                                            'pct': 0.7378}},
#                        'free': 162291712,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17017577472, 'pct': 0.9906}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:29.995Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 125},
#  'system': {'load': {'1': 3.6777,
#                      '15': 3.2632,
#                      '5': 3.3169,
#                      'norm': {'1': 0.4597, '15': 0.4079, '5': 0.4146}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:30.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 26},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8543},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0535},
#                     'user': {'pct': 0.0922}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:30.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 49},
#  'system': {'memory': {'actual': {'free': 4503785472,
#                                   'used': {'bytes': 12676083712,
#                                            'pct': 0.7378}},
#                        'free': 161177600,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17018691584, 'pct': 0.9906}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:30.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 72},
#  'system': {'load': {'1': 3.6777,
#                      '15': 3.2632,
#                      '5': 3.3169,
#                      'norm': {'1': 0.4597, '15': 0.4079, '5': 0.4146}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:31.999Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 33},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.8327},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0549},
#                     'user': {'pct': 0.1124}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:31.999Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 45},
#  'system': {'memory': {'actual': {'free': 4469145600,
#                                   'used': {'bytes': 12710723584,
#                                            'pct': 0.7399}},
#                        'free': 134561792,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17045307392, 'pct': 0.9922}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:31.999Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 84},
#  'system': {'load': {'1': 3.3828,
#                      '15': 3.2437,
#                      '5': 3.2617,
#                      'norm': {'1': 0.4229, '15': 0.4055, '5': 0.4077}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:32.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'cpu', 'rtt': 29},
#  'system': {'cpu': {'cores': 8,
#                     'idle': {'pct': 0.9036},
#                     'iowait': {'pct': 0.0},
#                     'irq': {'pct': 0.0},
#                     'nice': {'pct': 0.0},
#                     'softirq': {'pct': 0.0},
#                     'steal': {'pct': 0.0},
#                     'system': {'pct': 0.0438},
#                     'user': {'pct': 0.0526}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:32.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'memory', 'rtt': 46},
#  'system': {'memory': {'actual': {'free': 4467118080,
#                                   'used': {'bytes': 12712751104, 'pct': 0.74}},
#                        'free': 133783552,
#                        'swap': {'free': 1073479680,
#                                 'total': 1073741824,
#                                 'used': {'bytes': 262144, 'pct': 0.0002}},
#                        'total': 17179869184,
#                        'used': {'bytes': 17046085632, 'pct': 0.9922}}},
#  'type': 'metricsets'}
# {'@timestamp': '2017-04-27T23:08:32.997Z',
#  'beat': {'hostname': 'IPC-Admins-MacBook-Pro.local',
#           'name': 'My Mac Metrics',
#           'version': '5.3.1'},
#  'fields': {'env': 'macbook', 'mac': 'ac:bc:32:ab:e1:c9'},
#  'metricset': {'module': 'system', 'name': 'load', 'rtt': 82},
#  'system': {'load': {'1': 3.3828,
#                      '15': 3.2437,
#                      '5': 3.2617,
#                      'norm': {'1': 0.4229, '15': 0.4055, '5': 0.4077}}},
#  'type': 'metricsets'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7baf88f6df70> in <module>()
# ----> 1 for index, record in enumerate(consumer):
#       2     pprint.pprint(record.value)
#       3     if index > 50:
#       4         break
#
# /Users/julianp/dev/spikes/stats/.env3/lib/python3.6/site-packages/kafka/consumer/group.py in __next__(self)
#     962         self._set_consumer_timeout()
#     963         try:
# --> 964             return next(self._iterator)
#     965         except StopIteration:
#     966             self._iterator = None
#
# /Users/julianp/dev/spikes/stats/.env3/lib/python3.6/site-packages/kafka/consumer/group.py in _message_generator(self)
#     902             if not self._fetcher.in_flight_fetches():
#     903                 poll_ms = 0
# --> 904             self._client.poll(timeout_ms=poll_ms, sleep=True)
#     905
#     906             # We need to make sure we at least keep up with scheduled tasks,
#
# /Users/julianp/dev/spikes/stats/.env3/lib/python3.6/site-packages/kafka/client_async.py in poll(self, timeout_ms, future, sleep, delayed_tasks)
#     523                 timeout = max(0, timeout / 1000.0)  # avoid negative timeouts
#     524
# --> 525             responses.extend(self._poll(timeout, sleep=sleep))
#     526
#     527             # If all we had was a timeout (future is None) - only do one poll
#
# /Users/julianp/dev/spikes/stats/.env3/lib/python3.6/site-packages/kafka/client_async.py in _poll(self, timeout, sleep)
#     540
#     541         start_select = time.time()
# --> 542         ready = self._selector.select(timeout)
#     543         end_select = time.time()
#     544         if self._sensors:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/selectors.py in select(self, timeout)
#     575             ready = []
#     576             try:
# --> 577                 kev_list = self._kqueue.control(None, max_ev, timeout)
#     578             except InterruptedError:
#     579                 return ready
#
# KeyboardInterrupt:

# %%
def animate(i):
    graph_data = open('example.txt', 'r').read()
    lines = graph_data.split('\n')
    xs = []
    ys = []
    for line in lines:
        if len(line) > 1:
            x, y = line.split(',')
            xs.append(x)
            ys.append(y)
    ax1.clear()
    ax1.plot(xs, ys)
